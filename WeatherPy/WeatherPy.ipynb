# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 659

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&units=metric&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        weather_response = requests.get(city_url)
        city_weather = weather_response.json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | kavieng
# Processing Record 2 of Set 1 | la macarena
# Processing Record 3 of Set 1 | umm kaddadah
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | albany
# Processing Record 6 of Set 1 | texarkana
# Processing Record 7 of Set 1 | torbay
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | puerto ayora
# Processing Record 11 of Set 1 | mackenzie
# Processing Record 12 of Set 1 | bathsheba
# Processing Record 13 of Set 1 | eyl
# Processing Record 14 of Set 1 | khatanga
# Processing Record 15 of Set 1 | cayenne
# Processing Record 16 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 18 of Set 1 | nizhniy baskunchak
# Processing Record 19 of Set 1 | papagaios
# Processing Record 20 of Set 1 | mandalgovi
# Processing Record 21 of Set 1 | santa catalina
# Processing Record 22 of Set 1 | yanam
# Processing Record 23 of Set 1 | hasaki
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | trairi
# Processing Record 26 of Set 1 | dum duma
# Processing Record 27 of Set 1 | tiksi
# Processing Record 28 of Set 1 | hilo
# Processing Record 29 of Set 1 | codrington
# Processing Record 30 of Set 1 | avarua
# Processing Record 31 of Set 1 | formosa do rio preto
# Processing Record 32 of Set 1 | cabo san lucas
# Processing Record 33 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 34 of Set 1 | stephenville
# Processing Record 35 of Set 1 | huarmey
# Processing Record 36 of Set 1 | lebu
# Processing Record 37 of Set 1 | talaya
# Processing Record 38 of Set 1 | inuvik
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | cidreira
# Processing Record 41 of Set 1 | jamestown
# Processing Record 42 of Set 1 | lavrentiya
# Processing Record 43 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 1 | cape town
# Processing Record 45 of Set 1 | togur
# Processing Record 46 of Set 1 | mahebourg
# Processing Record 47 of Set 1 | le port
# Processing Record 48 of Set 1 | tessalit
# Processing Record 49 of Set 1 | turtkul
# City not found. Skipping...
# Processing Record 50 of Set 1 | lexington
# Processing Record 0 of Set 2 | longyearbyen
# Processing Record 1 of Set 2 | chokurdakh
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | liverpool
# Processing Record 4 of Set 2 | brae
# Processing Record 5 of Set 2 | rikitea
# Processing Record 6 of Set 2 | carnarvon
# Processing Record 7 of Set 2 | dikson
# Processing Record 8 of Set 2 | aklavik
# Processing Record 9 of Set 2 | belaya kholunitsa
# Processing Record 10 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 11 of Set 2 | narsaq
# Processing Record 12 of Set 2 | nantucket
# Processing Record 13 of Set 2 | balykshi
# Processing Record 14 of Set 2 | ostrovnoy
# Processing Record 15 of Set 2 | bubaque
# Processing Record 16 of Set 2 | tabas
# Processing Record 17 of Set 2 | barrow
# Processing Record 18 of Set 2 | tete
# Processing Record 19 of Set 2 | santiago del estero
# Processing Record 20 of Set 2 | hobart
# Processing Record 21 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 22 of Set 2 | tabuk
# Processing Record 23 of Set 2 | bengkulu
# Processing Record 24 of Set 2 | tuban
# Processing Record 25 of Set 2 | dauphin
# Processing Record 26 of Set 2 | kaitangata
# Processing Record 27 of Set 2 | richards bay
# Processing Record 28 of Set 2 | port alfred
# Processing Record 29 of Set 2 | ushuaia
# Processing Record 30 of Set 2 | zeya
# Processing Record 31 of Set 2 | thompson
# Processing Record 32 of Set 2 | helong
# Processing Record 33 of Set 2 | fortuna
# Processing Record 34 of Set 2 | qaanaaq
# Processing Record 35 of Set 2 | bluff
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | touros
# Processing Record 39 of Set 2 | east london
# Processing Record 40 of Set 2 | souillac
# Processing Record 41 of Set 2 | aksay
# Processing Record 42 of Set 2 | tezu
# Processing Record 43 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 44 of Set 2 | pevek
# Processing Record 45 of Set 2 | yellowknife
# Processing Record 46 of Set 2 | saskylakh
# Processing Record 47 of Set 2 | mar del plata
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | kuala selangor
# Processing Record 0 of Set 3 | gunjur
# Processing Record 1 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 3 | charleston
# Processing Record 3 of Set 3 | jinxiang
# Processing Record 4 of Set 3 | lorengau
# Processing Record 5 of Set 3 | gold coast
# Processing Record 6 of Set 3 | luganville
# Processing Record 7 of Set 3 | lata
# Processing Record 8 of Set 3 | abu samrah
# Processing Record 9 of Set 3 | samarai
# Processing Record 10 of Set 3 | severo-kurilsk
# Processing Record 11 of Set 3 | nabire
# Processing Record 12 of Set 3 | shingu
# Processing Record 13 of Set 3 | ponta do sol
# Processing Record 14 of Set 3 | dingle
# Processing Record 15 of Set 3 | kirakira
# Processing Record 16 of Set 3 | constitucion
# Processing Record 17 of Set 3 | pisco
# Processing Record 18 of Set 3 | goryachegorsk
# Processing Record 19 of Set 3 | victoria
# Processing Record 20 of Set 3 | rocha
# Processing Record 21 of Set 3 | toliary
# City not found. Skipping...
# Processing Record 22 of Set 3 | jizan
# Processing Record 23 of Set 3 | bethel
# Processing Record 24 of Set 3 | havelock
# Processing Record 25 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 26 of Set 3 | tura
# Processing Record 27 of Set 3 | livingston
# Processing Record 28 of Set 3 | nakhon nayok
# Processing Record 29 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 3 | kandrian
# Processing Record 31 of Set 3 | parabel
# Processing Record 32 of Set 3 | sinnar
# Processing Record 33 of Set 3 | aleksandrov gay
# Processing Record 34 of Set 3 | shenkursk
# Processing Record 35 of Set 3 | meulaboh
# Processing Record 36 of Set 3 | korem
# Processing Record 37 of Set 3 | drayton valley
# Processing Record 38 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 3 | port hardy
# Processing Record 40 of Set 3 | nome
# Processing Record 41 of Set 3 | neuquen
# Processing Record 42 of Set 3 | kavaratti
# Processing Record 43 of Set 3 | balagansk
# Processing Record 44 of Set 3 | kerki
# City not found. Skipping...
# Processing Record 45 of Set 3 | tiznit
# Processing Record 46 of Set 3 | atuona
# Processing Record 47 of Set 3 | ucluelet
# Processing Record 48 of Set 3 | port elizabeth
# Processing Record 49 of Set 3 | ortona
# Processing Record 0 of Set 4 | punta arenas
# Processing Record 1 of Set 4 | kalmthout
# Processing Record 2 of Set 4 | olafsvik
# Processing Record 3 of Set 4 | tuktoyaktuk
# Processing Record 4 of Set 4 | bardiyah
# Processing Record 5 of Set 4 | aswan
# Processing Record 6 of Set 4 | erzincan
# Processing Record 7 of Set 4 | evanston
# Processing Record 8 of Set 4 | kinablangan
# Processing Record 9 of Set 4 | tranas
# Processing Record 10 of Set 4 | mao
# Processing Record 11 of Set 4 | la romana
# Processing Record 12 of Set 4 | uruzgan
# Processing Record 13 of Set 4 | krasnoselkup
# Processing Record 14 of Set 4 | nizwa
# Processing Record 15 of Set 4 | flinders
# Processing Record 16 of Set 4 | padang
# Processing Record 17 of Set 4 | brownsville
# Processing Record 18 of Set 4 | finnsnes
# Processing Record 19 of Set 4 | cairns
# Processing Record 20 of Set 4 | sungaipenuh
# Processing Record 21 of Set 4 | klaksvik
# Processing Record 22 of Set 4 | saint-philippe
# Processing Record 23 of Set 4 | tasiilaq
# Processing Record 24 of Set 4 | la ronge
# Processing Record 25 of Set 4 | tabou
# Processing Record 26 of Set 4 | georgetown
# Processing Record 27 of Set 4 | ilulissat
# Processing Record 28 of Set 4 | the valley
# Processing Record 29 of Set 4 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 30 of Set 4 | kashi
# Processing Record 31 of Set 4 | ahipara
# Processing Record 32 of Set 4 | abu zabad
# Processing Record 33 of Set 4 | patrocinio
# Processing Record 34 of Set 4 | port blair
# Processing Record 35 of Set 4 | rojhan
# Processing Record 36 of Set 4 | imatra
# Processing Record 37 of Set 4 | kodiak
# Processing Record 38 of Set 4 | hithadhoo
# Processing Record 39 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 4 | tondano
# Processing Record 41 of Set 4 | suntar
# Processing Record 42 of Set 4 | vila franca do campo
# Processing Record 43 of Set 4 | celestun
# Processing Record 44 of Set 4 | saldanha
# Processing Record 45 of Set 4 | zhob
# Processing Record 46 of Set 4 | chambas
# Processing Record 47 of Set 4 | jussara
# Processing Record 48 of Set 4 | odweyne
# Processing Record 49 of Set 4 | port hedland
# Processing Record 0 of Set 5 | axim
# Processing Record 1 of Set 5 | ambatondrazaka
# Processing Record 2 of Set 5 | puri
# Processing Record 3 of Set 5 | madang
# Processing Record 4 of Set 5 | shimoda
# Processing Record 5 of Set 5 | north bend
# Processing Record 6 of Set 5 | benghazi
# Processing Record 7 of Set 5 | tougue
# Processing Record 8 of Set 5 | lobito
# Processing Record 9 of Set 5 | san vicente
# Processing Record 10 of Set 5 | flin flon
# Processing Record 11 of Set 5 | sioux lookout
# Processing Record 12 of Set 5 | kamenka
# Processing Record 13 of Set 5 | kloulklubed
# Processing Record 14 of Set 5 | new norfolk
# Processing Record 15 of Set 5 | tarudant
# City not found. Skipping...
# Processing Record 16 of Set 5 | saint george
# Processing Record 17 of Set 5 | miracema do tocantins
# Processing Record 18 of Set 5 | arraial do cabo
# Processing Record 19 of Set 5 | benguela
# Processing Record 20 of Set 5 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 5 | harbour breton
# Processing Record 22 of Set 5 | crab hill
# City not found. Skipping...
# Processing Record 23 of Set 5 | cervo
# Processing Record 24 of Set 5 | harper
# Processing Record 25 of Set 5 | maningrida
# Processing Record 26 of Set 5 | hualmay
# Processing Record 27 of Set 5 | ribeira grande
# Processing Record 28 of Set 5 | les cayes
# Processing Record 29 of Set 5 | palmer
# Processing Record 30 of Set 5 | cockburn town
# Processing Record 31 of Set 5 | honningsvag
# Processing Record 32 of Set 5 | natal
# Processing Record 33 of Set 5 | acarau
# Processing Record 34 of Set 5 | alice town
# Processing Record 35 of Set 5 | vestmanna
# Processing Record 36 of Set 5 | pelaya
# Processing Record 37 of Set 5 | boshan
# Processing Record 38 of Set 5 | barra do garcas
# Processing Record 39 of Set 5 | rawson
# Processing Record 40 of Set 5 | tuatapere
# Processing Record 41 of Set 5 | pregradnoye
# Processing Record 42 of Set 5 | sao joao da barra
# Processing Record 43 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 5 | kodinar
# Processing Record 45 of Set 5 | taoudenni
# Processing Record 46 of Set 5 | talnakh
# Processing Record 47 of Set 5 | bagdarin
# Processing Record 48 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 49 of Set 5 | ruidoso
# Processing Record 0 of Set 6 | isangel
# Processing Record 1 of Set 6 | raga
# Processing Record 2 of Set 6 | luderitz
# Processing Record 3 of Set 6 | mezen
# Processing Record 4 of Set 6 | waingapu
# Processing Record 5 of Set 6 | segezha
# Processing Record 6 of Set 6 | linxia
# Processing Record 7 of Set 6 | ijaki
# City not found. Skipping...
# Processing Record 8 of Set 6 | marovoay
# Processing Record 9 of Set 6 | evensk
# Processing Record 10 of Set 6 | vologda
# Processing Record 11 of Set 6 | ancud
# Processing Record 12 of Set 6 | mago
# Processing Record 13 of Set 6 | aksu
# Processing Record 14 of Set 6 | vallenar
# Processing Record 15 of Set 6 | hoi an
# Processing Record 16 of Set 6 | khazar
# Processing Record 17 of Set 6 | vila
# Processing Record 18 of Set 6 | nikolskoye
# Processing Record 19 of Set 6 | kosa
# Processing Record 20 of Set 6 | bonavista
# Processing Record 21 of Set 6 | mount isa
# Processing Record 22 of Set 6 | rosarito
# Processing Record 23 of Set 6 | yazd
# Processing Record 24 of Set 6 | riyadh
# Processing Record 25 of Set 6 | pittsburg
# Processing Record 26 of Set 6 | bossembele
# City not found. Skipping...
# Processing Record 27 of Set 6 | araouane
# Processing Record 28 of Set 6 | surt
# Processing Record 29 of Set 6 | villarrica
# Processing Record 30 of Set 6 | armacao dos buzios
# City not found. Skipping...
# Processing Record 31 of Set 6 | sentyabrskiy
# City not found. Skipping...
# Processing Record 32 of Set 6 | izhma
# Processing Record 33 of Set 6 | pampa
# Processing Record 34 of Set 6 | deputatskiy
# Processing Record 35 of Set 6 | quepos
# Processing Record 36 of Set 6 | cherskiy
# Processing Record 37 of Set 6 | sakakah
# Processing Record 38 of Set 6 | corsicana
# Processing Record 39 of Set 6 | chernyshevskiy
# Processing Record 40 of Set 6 | cap-aux-meules
# Processing Record 41 of Set 6 | ponta delgada
# Processing Record 42 of Set 6 | bom jesus
# Processing Record 43 of Set 6 | sistranda
# Processing Record 44 of Set 6 | vilyuysk
# Processing Record 45 of Set 6 | sabinas hidalgo
# Processing Record 46 of Set 6 | okhotsk
# Processing Record 47 of Set 6 | kutum
# Processing Record 48 of Set 6 | nelson bay
# Processing Record 49 of Set 6 | najran
# Processing Record 0 of Set 7 | juneau
# Processing Record 1 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 2 of Set 7 | khomeyn
# Processing Record 3 of Set 7 | lompoc
# Processing Record 4 of Set 7 | mugur-aksy
# Processing Record 5 of Set 7 | chagda
# City not found. Skipping...
# Processing Record 6 of Set 7 | kharovsk
# Processing Record 7 of Set 7 | puerto escondido
# Processing Record 8 of Set 7 | severomuysk
# Processing Record 9 of Set 7 | airai
# Processing Record 10 of Set 7 | bairiki
# Processing Record 11 of Set 7 | sabang
# Processing Record 12 of Set 7 | la asuncion
# Processing Record 13 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 14 of Set 7 | saint-jean-de-dieu
# City not found. Skipping...
# Processing Record 15 of Set 7 | bambous virieux
# Processing Record 16 of Set 7 | zlobin
# Processing Record 17 of Set 7 | media luna
# Processing Record 18 of Set 7 | paralimni
# Processing Record 19 of Set 7 | tazovskiy
# Processing Record 20 of Set 7 | baherden
# Processing Record 21 of Set 7 | mitu
# Processing Record 22 of Set 7 | egvekinot
# Processing Record 23 of Set 7 | coruripe
# Processing Record 24 of Set 7 | vestmannaeyjar
# Processing Record 25 of Set 7 | houma
# Processing Record 26 of Set 7 | norman wells
# Processing Record 27 of Set 7 | charters towers
# Processing Record 28 of Set 7 | idah
# Processing Record 29 of Set 7 | sokoni
# Processing Record 30 of Set 7 | guerrero negro
# Processing Record 31 of Set 7 | sao bartolomeu de messines
# Processing Record 32 of Set 7 | saint-augustin
# Processing Record 33 of Set 7 | namatanai
# Processing Record 34 of Set 7 | gibara
# Processing Record 35 of Set 7 | scottsburgh
# City not found. Skipping...
# Processing Record 36 of Set 7 | innisfail
# Processing Record 37 of Set 7 | edea
# Processing Record 38 of Set 7 | kytlym
# City not found. Skipping...
# Processing Record 39 of Set 7 | stornoway
# Processing Record 40 of Set 7 | kieta
# Processing Record 41 of Set 7 | young
# Processing Record 42 of Set 7 | dzerzhinsk
# Processing Record 43 of Set 7 | tres coracoes
# Processing Record 44 of Set 7 | santiago
# Processing Record 45 of Set 7 | taltal
# Processing Record 46 of Set 7 | walvis bay
# Processing Record 47 of Set 7 | krasnaya gora
# Processing Record 48 of Set 7 | shakiso
# Processing Record 49 of Set 7 | bridlington
# Processing Record 0 of Set 8 | mosquera
# Processing Record 1 of Set 8 | boa vista
# Processing Record 2 of Set 8 | qaqortoq
# Processing Record 3 of Set 8 | ereymentau
# Processing Record 4 of Set 8 | mancio lima
# Processing Record 5 of Set 8 | moron
# Processing Record 6 of Set 8 | maralal
# Processing Record 7 of Set 8 | herat
# Processing Record 8 of Set 8 | berdigestyakh
# Processing Record 9 of Set 8 | honiara
# Processing Record 10 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 11 of Set 8 | kruisfontein
# Processing Record 12 of Set 8 | necochea
# Processing Record 13 of Set 8 | belmopan
# Processing Record 14 of Set 8 | pankrushikha
# Processing Record 15 of Set 8 | wajima
# Processing Record 16 of Set 8 | aykhal
# Processing Record 17 of Set 8 | nosy varika
# Processing Record 18 of Set 8 | daru
# Processing Record 19 of Set 8 | half moon bay
# Processing Record 20 of Set 8 | myitkyina
# Processing Record 21 of Set 8 | cabedelo
# Processing Record 22 of Set 8 | havoysund
# Processing Record 23 of Set 8 | roald
# Processing Record 24 of Set 8 | tambura
# Processing Record 25 of Set 8 | indianola
# Processing Record 26 of Set 8 | portland
# Processing Record 27 of Set 8 | kosonsoy
# Processing Record 28 of Set 8 | koygorodok
# Processing Record 29 of Set 8 | moose factory
# Processing Record 30 of Set 8 | brigantine
# Processing Record 31 of Set 8 | mutsamudu
# City not found. Skipping...
# Processing Record 32 of Set 8 | panzhihua
# Processing Record 33 of Set 8 | malakal
# Processing Record 34 of Set 8 | mwene-ditu
# Processing Record 35 of Set 8 | yining
# Processing Record 36 of Set 8 | praia da vitoria
# Processing Record 37 of Set 8 | nang rong
# Processing Record 38 of Set 8 | segovia
# Processing Record 39 of Set 8 | nurota
# Processing Record 40 of Set 8 | sisophon
# Processing Record 41 of Set 8 | chandbali
# Processing Record 42 of Set 8 | gari
# Processing Record 43 of Set 8 | karpathos
# Processing Record 44 of Set 8 | te anau
# Processing Record 45 of Set 8 | vostok
# Processing Record 46 of Set 8 | santa cruz
# Processing Record 47 of Set 8 | upernavik
# Processing Record 48 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 49 of Set 8 | kanigoro
# Processing Record 0 of Set 9 | quarai
# Processing Record 1 of Set 9 | manjacaze
# Processing Record 2 of Set 9 | carandai
# Processing Record 3 of Set 9 | krasnyy chikoy
# Processing Record 4 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 9 | husavik
# Processing Record 6 of Set 9 | hay river
# Processing Record 7 of Set 9 | uzhur-4
# City not found. Skipping...
# Processing Record 8 of Set 9 | buala
# Processing Record 9 of Set 9 | quelimane
# Processing Record 10 of Set 9 | thinadhoo
# Processing Record 11 of Set 9 | paracatu
# Processing Record 12 of Set 9 | christchurch
# Processing Record 13 of Set 9 | okato
# Processing Record 14 of Set 9 | alghero
# Processing Record 15 of Set 9 | urumqi
# Processing Record 16 of Set 9 | pochutla
# Processing Record 17 of Set 9 | atar
# Processing Record 18 of Set 9 | salamiyah
# Processing Record 19 of Set 9 | esperance
# Processing Record 20 of Set 9 | gamba
# Processing Record 21 of Set 9 | clyde river
# Processing Record 22 of Set 9 | sur
# Processing Record 23 of Set 9 | augusto correa
# Processing Record 24 of Set 9 | aguimes
# Processing Record 25 of Set 9 | sabratah
# Processing Record 26 of Set 9 | tokur
# Processing Record 27 of Set 9 | broken hill
# Processing Record 28 of Set 9 | mentok
# City not found. Skipping...
# Processing Record 29 of Set 9 | nouadhibou
# Processing Record 30 of Set 9 | pecos
# Processing Record 31 of Set 9 | anzio
# Processing Record 32 of Set 9 | nha trang
# Processing Record 33 of Set 9 | mahasamund
# Processing Record 34 of Set 9 | halifax
# Processing Record 35 of Set 9 | vao
# Processing Record 36 of Set 9 | venice
# Processing Record 37 of Set 9 | poim
# Processing Record 38 of Set 9 | paysandu
# Processing Record 39 of Set 9 | zaozerne
# Processing Record 40 of Set 9 | miles city
# Processing Record 41 of Set 9 | townsville
# Processing Record 42 of Set 9 | baruun-urt
# Processing Record 43 of Set 9 | eucaliptus
# Processing Record 44 of Set 9 | hovd
# Processing Record 45 of Set 9 | chapais
# Processing Record 46 of Set 9 | santa cruz de la palma
# Processing Record 47 of Set 9 | muravlenko
# Processing Record 48 of Set 9 | vila velha
# Processing Record 49 of Set 9 | moranbah
# Processing Record 0 of Set 10 | ocean city
# Processing Record 1 of Set 10 | ascension
# Processing Record 2 of Set 10 | bilma
# Processing Record 3 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 4 of Set 10 | beyneu
# Processing Record 5 of Set 10 | bambanglipuro
# Processing Record 6 of Set 10 | guaraniacu
# Processing Record 7 of Set 10 | stara synyava
# Processing Record 8 of Set 10 | paamiut
# Processing Record 9 of Set 10 | taveta
# Processing Record 10 of Set 10 | oussouye
# Processing Record 11 of Set 10 | sal rei
# Processing Record 12 of Set 10 | presidencia roque saenz pena
# Processing Record 13 of Set 10 | richard toll
# City not found. Skipping...
# Processing Record 14 of Set 10 | caravelas
# Processing Record 15 of Set 10 | greensburg
# Processing Record 16 of Set 10 | morlaix
# Processing Record 17 of Set 10 | bitlis
# Processing Record 18 of Set 10 | sumbawa
# City not found. Skipping...
# Processing Record 19 of Set 10 | dunedin
# Processing Record 20 of Set 10 | williston
# Processing Record 21 of Set 10 | emporia
# Processing Record 22 of Set 10 | maykain
# City not found. Skipping...
# Processing Record 23 of Set 10 | mayo
# Processing Record 24 of Set 10 | gorin
# Processing Record 25 of Set 10 | itarema
# Processing Record 26 of Set 10 | sikonge
# Processing Record 27 of Set 10 | pangnirtung
# Processing Record 28 of Set 10 | freeport
# Processing Record 29 of Set 10 | belmonte
# Processing Record 30 of Set 10 | jinchengjiang
# City not found. Skipping...
# Processing Record 31 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 32 of Set 10 | sola
# Processing Record 33 of Set 10 | jiayuguan
# Processing Record 34 of Set 10 | alice springs
# Processing Record 35 of Set 10 | kremenki
# Processing Record 36 of Set 10 | majene
# Processing Record 37 of Set 10 | birao
# Processing Record 38 of Set 10 | olinda
# Processing Record 39 of Set 10 | rockland
# Processing Record 40 of Set 10 | beringovskiy
# Processing Record 41 of Set 10 | wasilla
# Processing Record 42 of Set 10 | kamina
# Processing Record 43 of Set 10 | vikhorevka
# Processing Record 44 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 45 of Set 10 | mapiripan
# Processing Record 46 of Set 10 | ondorhaan
# City not found. Skipping...
# Processing Record 47 of Set 10 | conner
# Processing Record 48 of Set 10 | navolato
# Processing Record 49 of Set 10 | prince rupert
# Processing Record 0 of Set 11 | shepsi
# Processing Record 1 of Set 11 | tianjin
# Processing Record 2 of Set 11 | geraldton
# Processing Record 3 of Set 11 | kostino
# Processing Record 4 of Set 11 | uarini
# Processing Record 5 of Set 11 | juifang
# City not found. Skipping...
# Processing Record 6 of Set 11 | shahr-e babak
# Processing Record 7 of Set 11 | avera
# Processing Record 8 of Set 11 | pimentel
# Processing Record 9 of Set 11 | aksarka
# Processing Record 10 of Set 11 | nadym
# Processing Record 11 of Set 11 | beloha
# Processing Record 12 of Set 11 | goderich
# Processing Record 13 of Set 11 | ixtapa
# Processing Record 14 of Set 11 | udachnyy
# Processing Record 15 of Set 11 | fort saint james
# Processing Record 16 of Set 11 | chaman
# Processing Record 17 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 18 of Set 11 | port-cartier
# Processing Record 19 of Set 11 | saint-louis
# Processing Record 20 of Set 11 | doembang nangbuat
# Processing Record 21 of Set 11 | san policarpo
# Processing Record 22 of Set 11 | yichun
# Processing Record 23 of Set 11 | snezhnogorsk
# Processing Record 24 of Set 11 | puerto colombia
# Processing Record 25 of Set 11 | thai binh
# Processing Record 26 of Set 11 | rincon
# Processing Record 27 of Set 11 | velasco ibarra
# Processing Record 28 of Set 11 | san patricio
# Processing Record 29 of Set 11 | altay
# Processing Record 30 of Set 11 | dois vizinhos
# Processing Record 31 of Set 11 | dejen
# Processing Record 32 of Set 11 | tymovskoye
# Processing Record 33 of Set 11 | shubarkuduk
# Processing Record 34 of Set 11 | nishihara
# Processing Record 35 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 11 | toronto
# Processing Record 37 of Set 11 | ivanava
# Processing Record 38 of Set 11 | biak
# Processing Record 39 of Set 11 | chegem
# Processing Record 40 of Set 11 | kahului
# Processing Record 41 of Set 11 | harbin
# Processing Record 42 of Set 11 | povenets
# Processing Record 43 of Set 11 | salym
# Processing Record 44 of Set 11 | eha amufu
# Processing Record 45 of Set 11 | karabuk
# Processing Record 46 of Set 11 | kalemie
# Processing Record 47 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 48 of Set 11 | camopi
# Processing Record 49 of Set 11 | sungairaya
# Processing Record 0 of Set 12 | mogadishu
# Processing Record 1 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 2 of Set 12 | kassala
# Processing Record 3 of Set 12 | seminole
# Processing Record 4 of Set 12 | kolokani
# Processing Record 5 of Set 12 | faanui
# Processing Record 6 of Set 12 | qandala
# Processing Record 7 of Set 12 | iquitos
# Processing Record 8 of Set 12 | nalut
# Processing Record 9 of Set 12 | san pedro
# Processing Record 10 of Set 12 | vysokogornyy
# Processing Record 11 of Set 12 | tecolutla
# Processing Record 12 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 12 | aghavnadzor
# Processing Record 14 of Set 12 | skibbereen
# Processing Record 15 of Set 12 | bijie
# Processing Record 16 of Set 12 | barabai
# Processing Record 17 of Set 12 | glens falls
# Processing Record 18 of Set 12 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 12 | rota
# Processing Record 20 of Set 12 | banon
# Processing Record 21 of Set 12 | burgos
# Processing Record 22 of Set 12 | blagoyevo
# Processing Record 23 of Set 12 | lahaina
# Processing Record 24 of Set 12 | shizunai
# Processing Record 25 of Set 12 | turukhansk
# Processing Record 26 of Set 12 | encruzilhada do sul
# Processing Record 27 of Set 12 | kitob
# Processing Record 28 of Set 12 | nazarovo
# Processing Record 29 of Set 12 | altamira
# Processing Record 30 of Set 12 | sidi ali
# Processing Record 31 of Set 12 | nicoya
# Processing Record 32 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 12 | zdunska wola
# Processing Record 34 of Set 12 | diamantino
# Processing Record 35 of Set 12 | urgut
# Processing Record 36 of Set 12 | byron bay
# Processing Record 37 of Set 12 | comodoro rivadavia
# Processing Record 38 of Set 12 | kyren
# Processing Record 39 of Set 12 | iskateley
# Processing Record 40 of Set 12 | korla
# Processing Record 41 of Set 12 | isfana
# Processing Record 42 of Set 12 | zhanaozen
# Processing Record 43 of Set 12 | gravdal
# Processing Record 44 of Set 12 | llata
# Processing Record 45 of Set 12 | soldotna
# Processing Record 46 of Set 12 | cartagena
# Processing Record 47 of Set 12 | jalu
# Processing Record 48 of Set 12 | ojinaga
# Processing Record 49 of Set 12 | masuda
# Processing Record 0 of Set 13 | conceicao da barra
# Processing Record 1 of Set 13 | coquimbo
# Processing Record 2 of Set 13 | koslan
# Processing Record 3 of Set 13 | novoagansk
# Processing Record 4 of Set 13 | maniitsoq
# Processing Record 5 of Set 13 | mayumba
# Processing Record 6 of Set 13 | sebastian
# Processing Record 7 of Set 13 | okha
# Processing Record 8 of Set 13 | opuwo
# Processing Record 9 of Set 13 | vangaindrano
# Processing Record 10 of Set 13 | hami
# Processing Record 11 of Set 13 | awjilah
# Processing Record 12 of Set 13 | iqaluit
# Processing Record 13 of Set 13 | kaniama
# Processing Record 14 of Set 13 | chumikan
# Processing Record 15 of Set 13 | mpanda
# Processing Record 16 of Set 13 | marawi
# Processing Record 17 of Set 13 | yulara
# Processing Record 18 of Set 13 | sakaiminato
# Processing Record 19 of Set 13 | tashtagol
# Processing Record 20 of Set 13 | bull savanna
# Processing Record 21 of Set 13 | baie-comeau
# Processing Record 22 of Set 13 | prudy
# Processing Record 23 of Set 13 | florida
# Processing Record 24 of Set 13 | athabasca
# Processing Record 25 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 26 of Set 13 | malyye derbety
# Processing Record 27 of Set 13 | labuhan
# Processing Record 28 of Set 13 | san jeronimo
# Processing Record 29 of Set 13 | hare bay
# Processing Record 30 of Set 13 | wahran
# City not found. Skipping...
# Processing Record 31 of Set 13 | correntina
# Processing Record 32 of Set 13 | yabrud
# Processing Record 33 of Set 13 | xuddur
# Processing Record 34 of Set 13 | ulladulla
# Processing Record 35 of Set 13 | nyaunglebin
# Processing Record 36 of Set 13 | spirovo
# Processing Record 37 of Set 13 | verkhnevilyuysk
# Processing Record 38 of Set 13 | arlit
# Processing Record 39 of Set 13 | srednekolymsk
# Processing Record 40 of Set 13 | xining
# Processing Record 41 of Set 13 | homer
# Processing Record 42 of Set 13 | goya
# Processing Record 43 of Set 13 | longavi
# Processing Record 44 of Set 13 | baker city
# Processing Record 45 of Set 13 | maceio
# Processing Record 46 of Set 13 | ladario
# Processing Record 47 of Set 13 | coihaique
# Processing Record 48 of Set 13 | salumbar
# Processing Record 49 of Set 13 | coahuayana
# Processing Record 0 of Set 14 | salalah
# Processing Record 1 of Set 14 | kanakapura
# Processing Record 2 of Set 14 | panguna
# Processing Record 3 of Set 14 | gilbues
# Processing Record 4 of Set 14 | miyazu
# Processing Record 5 of Set 14 | guangyuan
# Processing Record 6 of Set 14 | yar-sale
# Processing Record 7 of Set 14 | long beach
# Processing Record 8 of Set 14 | khonuu
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          604
# Lat           604
# Lng           604
# Max Temp      604
# Humidity      604
# Cloudiness    604
# Wind Speed    604
# Country       604
# Date          604
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       kavieng  -2.5744  150.7967     27.28        77          51
# 1   la macarena   2.1837  -73.7849     29.79        51          28
# 2  umm kaddadah  13.6017   26.6876     29.40        15          25
# 3       mataura -46.1927  168.8643      6.68        99          14
# 4        albany  42.6001  -73.9662      1.64        74          95
#
#    Wind Speed Country        Date
# 0        3.02      PG  1674570887
# 1        2.77      CO  1674570887
# 2        6.84      SD  1674570887
# 3        0.92      NZ  1674570887
# 4        5.39      US  1674570887

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20900\1599256203.py in <module>
#       1 # Read saved data
# ----> 2 city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")
#       3
#       4 # Display sample data
#       5 city_data_df.head()
#
# c:\Users\daleh\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# c:\Users\daleh\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# c:\Users\daleh\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# c:\Users\daleh\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# c:\Users\daleh\anaconda3\envs\PythonData\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File output_data/cities.csv does not exist: 'output_data/cities.csv'

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
#Convert to Integers
city_data_df['Lat'] =pd.to_numeric(city_data_df['Lat'])
city_data_df['Max Temp'] =pd.to_numeric(city_data_df['Max Temp'])
city_data_df['Humidity'] =pd.to_numeric(city_data_df['Humidity'])
city_data_df['Cloudiness'] =pd.to_numeric(city_data_df['Cloudiness'])
city_data_df['Wind Speed'] =pd.to_numeric(city_data_df['Wind Speed'])
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       kavieng  -2.5744  150.7967     27.28        77          51
# 1   la macarena   2.1837  -73.7849     29.79        51          28
# 2  umm kaddadah  13.6017   26.6876     29.40        15          25
# 3       mataura -46.1927  168.8643      6.68        99          14
# 4        albany  42.6001  -73.9662      1.64        74          95
#
#    Wind Speed Country        Date
# 0        3.02      PG  1674570887
# 1        2.77      CO  1674570887
# 2        6.84      SD  1674570887
# 3        0.92      NZ  1674570887
# 4        5.39      US  1674570887

# %%
# Build scatter plot for latitude vs. temperature
city_data_df.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, figsize=(9,9))

# Incorporate the other graph properties
plt.title("City Max Latitude vs Temperature (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature")
# Save the figure
#plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
city_data_df.plot(kind="scatter", x="Lat", y="Humidity", grid=True, figsize=(8,8))

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
# Save the figure
#plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
city_data_df.plot(kind="scatter", x="Lat", y="Cloudiness", grid=True, figsize=(8,8))

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
# Save the figure
#plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
city_data_df.plot(kind="scatter", x="Lat", y="Wind Speed", grid=True, figsize=(8,8))

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed (2022-10-18)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
# Save the figure
#plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
x_values = city_data_df['Lat']
y_values = city_data_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')

plt.show()
# Out:
# The r-value is: 0.7161472181434118

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')

plt.show()
# Out:
# The r-value is: 0.4121057168607245

# %% [markdown]
# **Discussion about the linear relationship:** There is a direct corrolation between the temperature and the lattitude. The lower the lattitude (ie from -50 to 0) the higher the temperature. Similarly, the greater the move from lattitude of 0 towards 80, the more the temperature declines.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')

#plt.savefig("output_data/fig1.png")

plt.show()
# Out:
# The r-value is: 0.05689741545789598

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity')

#plt.savefig("output_data/Fig1.png")

plt.show()
# Out:
# The r-value is: 0.0002808747046324607

# %% [markdown]
# **Discussion about the linear relationship:** Not a close linear corrolation so quite a lot of variance.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

#plt.savefig("output_data/Fig1.png")

plt.show()
# Out:
# The r-value is: 0.024026517125811015

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')

#plt.savefig("output_data/Fig1.png")

plt.show()
# Out:
# The r-value is: 0.02056735429994368

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

#plt.savefig("output_data/Fig1.png")

plt.show()
# Out:
# The r-value is: 0.030396762354449467

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')

#plt.savefig("output_data/Fig1.png")

plt.show()
# Out:
# The r-value is: 0.062239040700515696

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
